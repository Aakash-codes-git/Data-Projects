# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2005Accidents.txt',sep=',',header=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315434 entries, 0 to 315433
# Data columns (total 47 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       315434 non-null  object
#  1   1       315434 non-null  object
#  2   2       315434 non-null  object
#  3   3       315434 non-null  object
#  4   4       315434 non-null  object
#  5   5       315434 non-null  object
#  6   6       315434 non-null  object
#  7   7       315434 non-null  object
#  8   8       315434 non-null  object
#  9   9       315434 non-null  int64
#  10  10      315434 non-null  int64
#  11  11      315434 non-null  int64
#  12  12      315434 non-null  int64
#  13  13      315434 non-null  object
#  14  14      315434 non-null  object
#  15  15      315434 non-null  object
#  16  16      315434 non-null  object
#  17  17      315434 non-null  int64
#  18  18      315434 non-null  int64
#  19  19      315434 non-null  object
# ...

# %%
df['Year'] = 2005

# %%
df.head(3)
# Out:
#                                  0             1                         2  \
# 0  20050101#2005-4976               ATLANTIC      ABSECON CITY
# 1  20050101#2005-5721               ATLANTIC      ABSECON CITY
# 2  20050101#2005-5724               ATLANTIC      ABSECON CITY
#
#             3   4     5   6                          7                8  9  \
# 0  05/04/2005  W   2040  1   ABSECON                    MUNICIPAL COMP?  0
# 1  05/21/2005  SA  1431  1   ABSECON                    MUNICIPAL COMP?  0
# 2  05/21/2005  SA  1759  1   ABSECON                    MUNICIPAL COMP?  0
#
#    ...                         38  39  40  41        42        43 44  \
# 0  ...                                 25                          N
# 1  ...                                 35                          N
# 2  ...                                 25                          N
#
#                                                   45     46  Year
# ...

# %%
df_sample = df.copy()

# %%
df_sample.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department',
                  8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed',12:'Pedestrians Injured', 13:'Severity', 14:'Intersection',
                  15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location',20:'Location Direction',21:'Route',
                  22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',
                  29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',
                  34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction',
                  40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},
                  axis = 1, inplace=True
)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315434 entries, 0 to 315433
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          315434 non-null  object
#  1   County Name                       315434 non-null  object
#  2   Municipality Name                 315434 non-null  object
#  3   Crash Date                        315434 non-null  object
#  4   Crash Day of Week                 315434 non-null  object
#  5   Crash Time                        315434 non-null  object
#  6   Police Department Code            315434 non-null  object
#  7   Police Department                 315434 non-null  object
#  8   Police Station                    315434 non-null  object
#  9   Total Killed                      315434 non-null  int64
#  10  Total Injured                     315434 non-null  int64
# ...

# %%
df_sample.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20050101#2005-4976               ATLANTIC      ABSECON CITY
# 1  20050101#2005-5721               ATLANTIC      ABSECON CITY
# 2  20050101#2005-5724               ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  05/04/2005                W        2040                     1
# 1  05/21/2005                SA       1431                     1
# 2  05/21/2005                SA       1759                     1
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ABSECON                    MUNICIPAL COMP?             0  ...
# 1  ABSECON                    MUNICIPAL COMP?             0  ...
# 2  ABSECON                    MUNICIPAL COMP?             0  ...
#
#      Ramp To/From Route Name  Ramp To/From Direction  Posted Speed  \
# 0                                                               25
# ...

# %%
df1 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2006Accidents.txt', sep=',', header=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (30) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295546 entries, 0 to 295545
# Data columns (total 47 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       295546 non-null  object
#  1   1       295546 non-null  object
#  2   2       295546 non-null  object
#  3   3       295546 non-null  object
#  4   4       295546 non-null  object
#  5   5       295546 non-null  object
#  6   6       295546 non-null  object
#  7   7       295546 non-null  object
#  8   8       295546 non-null  object
#  9   9       295546 non-null  int64
#  10  10      295546 non-null  int64
#  11  11      295546 non-null  int64
#  12  12      295546 non-null  int64
#  13  13      295546 non-null  object
#  14  14      295546 non-null  object
#  15  15      295546 non-null  object
#  16  16      295546 non-null  object
#  17  17      295546 non-null  object
#  18  18      295546 non-null  int64
#  19  19      295546 non-null  object
# ...

# %%
df1['Year'] = 2006

# %%
df_sample1 = df1.copy()

# %%
df_sample1.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department',
                  8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed',12:'Pedestrians Injured', 13:'Severity', 14:'Intersection',
                  15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location',20:'Location Direction',21:'Route',
                  22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',
                  29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',
                  34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction',
                  40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},
                  axis = 1, inplace=True
)

# %%
df_sample1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295546 entries, 0 to 295545
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          295546 non-null  object
#  1   County Name                       295546 non-null  object
#  2   Municipality Name                 295546 non-null  object
#  3   Crash Date                        295546 non-null  object
#  4   Crash Day of Week                 295546 non-null  object
#  5   Crash Time                        295546 non-null  object
#  6   Police Department Code            295546 non-null  object
#  7   Police Department                 295546 non-null  object
#  8   Police Station                    295546 non-null  object
#  9   Total Killed                      295546 non-null  int64
#  10  Total Injured                     295546 non-null  int64
# ...

# %%
df_sample1.head(2)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  2006010106-034793                ATLANTIC      ABSECON CITY
# 1  2006010106-051065                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  03/24/2006                F        1629                     01
# 1  04/29/2006                SA       1254                     01
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ATLANTIC CITY              TRAFFIC                     0  ...
# 1  ATLANTIC CITY              AIU                         0  ...
#
#      Ramp To/From Route Name  Ramp To/From Direction  Posted Speed  \
# 0                                                               50
# 1                                                                0
#
#   Posted Speed Cross Street  Latitude Longitude Cell Phone In Use Flag  \
# 0                            39.39463  74.49178                      N
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2007Accidents.txt',sep=',',header=None)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306816 entries, 0 to 306815
# Data columns (total 47 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       306816 non-null  object
#  1   1       306816 non-null  object
#  2   2       306816 non-null  object
#  3   3       306816 non-null  object
#  4   4       306816 non-null  object
#  5   5       306816 non-null  object
#  6   6       306816 non-null  object
#  7   7       306816 non-null  object
#  8   8       306816 non-null  object
#  9   9       306816 non-null  int64
#  10  10      306816 non-null  int64
#  11  11      306816 non-null  int64
#  12  12      306816 non-null  int64
#  13  13      306816 non-null  object
#  14  14      306816 non-null  object
#  15  15      306816 non-null  object
#  16  16      306816 non-null  object
#  17  17      306816 non-null  object
#  18  18      306816 non-null  int64
#  19  19      306816 non-null  object
# ...

# %%
df2['Year']=2007

# %%
df_sample2 = df2.copy()

# %%
df_sample2.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department',
                  8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed',12:'Pedestrians Injured', 13:'Severity', 14:'Intersection',
                  15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location',20:'Location Direction',21:'Route',
                  22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',
                  29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',
                  34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction',
                  40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},
                  axis = 1, inplace=True
)

# %%
df_sample2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306816 entries, 0 to 306815
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          306816 non-null  object
#  1   County Name                       306816 non-null  object
#  2   Municipality Name                 306816 non-null  object
#  3   Crash Date                        306816 non-null  object
#  4   Crash Day of Week                 306816 non-null  object
#  5   Crash Time                        306816 non-null  object
#  6   Police Department Code            306816 non-null  object
#  7   Police Department                 306816 non-null  object
#  8   Police Station                    306816 non-null  object
#  9   Total Killed                      306816 non-null  int64
#  10  Total Injured                     306816 non-null  int64
# ...

# %%
df_sample2.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  2007010107-018522                ATLANTIC      ABSECON CITY
# 1  2007010107-046478                ATLANTIC      ABSECON CITY
# 2  2007010107-052297                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  02/15/2007                TH       1613                     01
# 1  04/25/2007                W        0946                     01
# 2  05/08/2007                TU       1015                     01
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ATLANTIC CITY              TRAFFIC                     0  ...
# 1  ATLANTIC CITY              ACCIDENT BUREAU             0  ...
# 2  ATLANTIC CITY              AIU                         0  ...
#
#      Ramp To/From Route Name  Ramp To/From Direction  Posted Speed  \
# 0                                                               50
# ...

# %%
df3 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2008Accidents.txt',sep=',',header=None)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303013 entries, 0 to 303012
# Data columns (total 47 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       303013 non-null  object
#  1   1       303013 non-null  object
#  2   2       303013 non-null  object
#  3   3       303013 non-null  object
#  4   4       303013 non-null  object
#  5   5       303013 non-null  object
#  6   6       303013 non-null  object
#  7   7       303013 non-null  object
#  8   8       303013 non-null  object
#  9   9       303013 non-null  int64
#  10  10      303013 non-null  int64
#  11  11      303013 non-null  int64
#  12  12      303013 non-null  int64
#  13  13      303013 non-null  object
#  14  14      303013 non-null  object
#  15  15      303013 non-null  object
#  16  16      303013 non-null  object
#  17  17      303013 non-null  object
#  18  18      303013 non-null  int64
#  19  19      303013 non-null  object
# ...

# %%
df3['Year']=2008

# %%
df_sample3=df3.copy()

# %%
df_sample3.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department',
                  8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed',12:'Pedestrians Injured', 13:'Severity', 14:'Intersection',
                  15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location',20:'Location Direction',21:'Route',
                  22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',
                  29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',
                  34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction',
                  40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},
                  axis = 1, inplace=True
)

# %%
df_sample3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303013 entries, 0 to 303012
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          303013 non-null  object
#  1   County Name                       303013 non-null  object
#  2   Municipality Name                 303013 non-null  object
#  3   Crash Date                        303013 non-null  object
#  4   Crash Day of Week                 303013 non-null  object
#  5   Crash Time                        303013 non-null  object
#  6   Police Department Code            303013 non-null  object
#  7   Police Department                 303013 non-null  object
#  8   Police Station                    303013 non-null  object
#  9   Total Killed                      303013 non-null  int64
#  10  Total Injured                     303013 non-null  int64
# ...

# %%
df_sample3.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  2008010108-026816                ATLANTIC      ABSECON CITY
# 1  2008010108-163190                ATLANTIC      ABSECON CITY
# 2  2008010108-24779                 ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  03/04/2008                TU       1539                     01
# 1  12/19/2008                F        1114                     01
# 2  11/25/2008                TU       0345                     99
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ATLANTIC CITY              AIU                         0  ...
# 1  ATLANTIC CITY              TRAFFIC                     0  ...
# 2  NJ TRANSIT P.D.            ATLANTIC CITY               0  ...
#
#      Ramp To/From Route Name  Ramp To/From Direction  Posted Speed  \
# 0                                                               50
# ...

# %%
df4 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2009Accidents.txt',sep=',',header=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301233 entries, 0 to 301232
# Data columns (total 47 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       301233 non-null  object
#  1   1       301233 non-null  object
#  2   2       301233 non-null  object
#  3   3       301233 non-null  object
#  4   4       301233 non-null  object
#  5   5       301233 non-null  object
#  6   6       301233 non-null  object
#  7   7       301233 non-null  object
#  8   8       301233 non-null  object
#  9   9       301233 non-null  int64
#  10  10      301233 non-null  int64
#  11  11      301233 non-null  int64
#  12  12      301233 non-null  int64
#  13  13      301233 non-null  object
#  14  14      301233 non-null  object
#  15  15      301233 non-null  object
#  16  16      301233 non-null  object
#  17  17      301233 non-null  object
#  18  18      301233 non-null  int64
#  19  19      301233 non-null  object
# ...

# %%
df4['Year']=2009

# %%
df_sample4 = df4.copy()

# %%
df_sample4.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department',
                  8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed',12:'Pedestrians Injured', 13:'Severity', 14:'Intersection',
                  15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location',20:'Location Direction',21:'Route',
                  22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',
                  29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',
                  34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction',
                  40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},
                  axis = 1, inplace=True
)

# %%
df_sample4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301233 entries, 0 to 301232
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          301233 non-null  object
#  1   County Name                       301233 non-null  object
#  2   Municipality Name                 301233 non-null  object
#  3   Crash Date                        301233 non-null  object
#  4   Crash Day of Week                 301233 non-null  object
#  5   Crash Time                        301233 non-null  object
#  6   Police Department Code            301233 non-null  object
#  7   Police Department                 301233 non-null  object
#  8   Police Station                    301233 non-null  object
#  9   Total Killed                      301233 non-null  int64
#  10  Total Injured                     301233 non-null  int64
# ...

# %%
df_sample4.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  2009010109-14497                 ATLANTIC      ABSECON CITY
# 1  2009010109-2898                  ATLANTIC      ABSECON CITY
# 2  200901012009-34176               ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  10/20/2009                TU       1648                     01
# 1  11/07/2009                SA       1611                     01
# 2  07/30/2009                TH       1133                     01
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  EAST WINDSOR TWP PD        TRAFFIC UNIT                0  ...
# 1  BLOOMINGDALE BORO PD                                   0  ...
# 2  PLEASANTVILLE PD                                       0  ...
#
#      Ramp To/From Route Name  Ramp To/From Direction  Posted Speed  \
# 0                                                                0
# ...

# %%
dfm = df_sample.append([df_sample1,df_sample2,df_sample3,df_sample4],ignore_index=True)

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1522042 entries, 0 to 1522041
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   Crash_ID                          1522042 non-null  object
#  1   County Name                       1522042 non-null  object
#  2   Municipality Name                 1522042 non-null  object
#  3   Crash Date                        1522042 non-null  object
#  4   Crash Day of Week                 1522042 non-null  object
#  5   Crash Time                        1522042 non-null  object
#  6   Police Department Code            1522042 non-null  object
#  7   Police Department                 1522042 non-null  object
#  8   Police Station                    1522042 non-null  object
#  9   Total Killed                      1522042 non-null  int64
#  10  Total Injured                     1522042 non-null  int64
# ...

# %%
dfm.tail(3)
# Out:
#                                 Crash_ID   County Name  \
# 1522039  20092123B150200953A              WARREN
# 1522040  20092123E15-2009-00001P          WARREN
# 1522041  20092123OIT-09166343             WARREN
#
#                 Municipality Name  Crash Date Crash Day of Week Crash Time  \
# 1522039  WHITE TWP                 01/29/2009                TH       1010
# 1522040  WHITE TWP                 01/07/2009                W        1235
# 1522041  WHITE TWP                 07/19/2009                S        1540
#
#         Police Department Code          Police Department   Police Station  \
# 1522039                     02  NEW JERSEY STATE POLICE    WASHINGTON
# 1522040                     02  NEW JERSEY STATE POLICE    WASHINGTON B150
# 1522041                     02  NEW JERSEY STATE POLICE    WASHINGTON
#
#          Total Killed  ...    Ramp To/From Route Name  Ramp To/From Direction  \
# 1522039             0  ...
# 1522040             0  ...
# ...

# %%
from google.colab import drive

#drive.mount('/content/drive')
path = '/content/drive/MyDrive/NJ_Clean Data/NJ_Accidents(2005-2009).csv'

with open(path, 'w', encoding = 'utf-8-sig') as f:
  dfm.to_csv(f)
