# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.ExcelFile('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/2001_Accidents_1st clean/NJ_2001_Accidents_headers.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-82d6b35fe67c> in <cell line: 1>()
# ----> 1 df = pd.ExcelFile('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/2001_Accidents_1st clean/NJ_2001_Accidents_headers.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1561                 ext = "xls"
#    1562             else:
# -> 1563                 ext = inspect_excel_format(
#    1564                     content_or_path=path_or_buffer, storage_options=storage_options
#    1565                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1417         content_or_path = BytesIO(content_or_path)
#    1418
# -> 1419     with get_handle(
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312696 entries, 0 to 312695
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          312696 non-null  object
#  1   County Name                       312696 non-null  object
#  2   Municipality Name                 312696 non-null  object
#  3   Crash Date                        312696 non-null  object
#  4   Crash Day of Week                 312696 non-null  object
#  5   Crash Time                        312696 non-null  object
#  6   Police Department Code            312696 non-null  object
#  7   Police Department                 312696 non-null  object
#  8   Police Department.1               312696 non-null  object
#  9   Total Killed                      312696 non-null  int64
#  10  Total Injured                     312696 non-null  float64
# ...

# %%
df.head(4)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20010101#2001-17846              ATLANTIC      ABSECON CITY
# 1  2001010101-00029                 ATLANTIC      ABSECON CITY
# 2  2001010101-004615                ATLANTIC      ABSECON CITY
# 3  2001010101-004880                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  12/21/2001                F        1834                     01
# 1  01/01/2001                M        0930                     1
# 2  04/10/2001                TU       1444                     1
# 3  04/15/2001                S        1356                     1
#
#            Police Department Police Department.1  Total Killed  ...  Is Ramp  \
# 0  ABSECON CITY                  MUNICIPAL COMP?             0  ...       .2
# 1  ABSECON                                                   0  ...
# 2  ABSECON                                                   0  ...
# ...

# %%
df.tail(3)
# Out:
#                                Crash_ID   County Name  \
# 312693  20012123B5001269A                WARREN
# 312694  20012123B??001285A               WARREN
# 312695  20012123BI500105A                WARREN
#
#                Municipality Name  Crash Date Crash Day of Week Crash Time  \
# 312693  WHITE TWP                 10/07/2001                S        1415
# 312694  WHITE TWP                 10/20/2001                SA       1900
# 312695  WHITE TWP                 01/03/2001                W        1340
#
#        Police Department Code          Police Department Police Department.1  \
# 312693                     2   STATE POLICE                  WASHINGTON
# 312694                     2   STATE POLICE                  WASHINGTON
# 312695                     2   STATE POLICE                  WASHINGTON
#
#         Total Killed  ...  Is Ramp    Ramp To/From Route Name  \
# 312693             0  ...
# 312694             0  ...
# 312695             0  ...
#
# ...

# %%
df.rename({'Police Department.1':'Police Station'},axis=1,inplace=True)
df['Year'] = 2001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312696 entries, 0 to 312695
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          312696 non-null  object
#  1   County Name                       312696 non-null  object
#  2   Municipality Name                 312696 non-null  object
#  3   Crash Date                        312696 non-null  object
#  4   Crash Day of Week                 312696 non-null  object
#  5   Crash Time                        312696 non-null  object
#  6   Police Department Code            312696 non-null  object
#  7   Police Department                 312696 non-null  object
#  8   Police Station                    312696 non-null  object
#  9   Total Killed                      312696 non-null  int64
#  10  Total Injured                     312696 non-null  float64
# ...

# %%
df_sample = df.copy()

# %%
df1 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2002Accidents.txt',sep=',',header=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head(4)
# Out:
#                                 0             1                         2   \
# 0  20020101#02-3806                 ATLANTIC      ABSECON CITY
# 1  20020101#2002-19775              ATLANTIC      ABSECON CITY
# 2  2002010101-4114                  ATLANTIC      ABSECON CITY
# 3  2002010102-001140                ATLANTIC      ABSECON CITY
#
#            3   4     5   6                          7                8   9   \
# 0  02/26/2002  TU  1850  01  ABSECON CITY               MUNICIPAL COMP?   0
# 1  11/29/2002  F   1727  01  ABSECON CITY               MUNICIPAL COMP?   0
# 2  03/03/2002  S   1448      ABSECON CITY                                 0
# 3  01/20/2002  S   0025      ABSECON                    MUNICIPAL COMP?   0
#
#    ...  37                         38  39  40  41        42        43  44  \
# 0  ...                                     50                           N
# 1  ...                                     40                           N
# ...

# %%
#frames = [df,df1]
#df_new = pd.concat(frames, ignore_index=True)
df1['Year'] = 2002

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319979 entries, 0 to 319978
# Data columns (total 48 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       319979 non-null  object
#  1   1       319979 non-null  object
#  2   2       319979 non-null  object
#  3   3       319979 non-null  object
#  4   4       319979 non-null  object
#  5   5       319979 non-null  object
#  6   6       319979 non-null  object
#  7   7       319979 non-null  object
#  8   8       319979 non-null  object
#  9   9       319979 non-null  int64
#  10  10      319979 non-null  int64
#  11  11      319979 non-null  int64
#  12  12      319979 non-null  int64
#  13  13      319979 non-null  object
#  14  14      319979 non-null  object
#  15  15      319979 non-null  object
#  16  16      319979 non-null  object
#  17  17      319979 non-null  int64
#  18  18      319979 non-null  int64
#  19  19      319979 non-null  object
# ...

# %%
df_sample1 = df1.copy()

# %%
df_sample1.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department'}, axis=1, inplace=True)

# %%
df_sample1.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20020101#02-3806                 ATLANTIC      ABSECON CITY
# 1  20020101#2002-19775              ATLANTIC      ABSECON CITY
# 2  2002010101-4114                  ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  02/26/2002                TU       1850                     01
# 1  11/29/2002                F        1727                     01
# 2  03/03/2002                S        1448
#
#            Police Department                8  9  ...  \
# 0  ABSECON CITY               MUNICIPAL COMP?  0  ...
# 1  ABSECON CITY               MUNICIPAL COMP?  0  ...
# 2  ABSECON CITY                                0  ...
#
#                           38  39  40  41        42        43 44  \
# 0                                 50                          N
# 1                                 40                          N
# ...

# %%
df_sample1.rename({8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed', 12:'Pedestrians Injured', 13:'Severity', 14:'Intersection', 15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location'}, axis=1, inplace=True)

# %%
columns1 = ['County Name','Municipality Name','Crash Date','Crash Day of Week','Crash Time','Police Department Code']
columns2 = ['Police Station', 'Total Killed', 'Total Injured', 'Pedestrians Killed', 'Pedestrians Injured', 'Severity', 'Intersection', 'Alcohol Involved', 'HazMat Involved', 'Crash Type Code', 'Total Vehicles Involved', 'Crash Location']
df_sample1[columns1].head(2)
# Out:
#     County Name         Municipality Name  Crash Date Crash Day of Week  \
# 0  ATLANTIC      ABSECON CITY              02/26/2002                TU
# 1  ATLANTIC      ABSECON CITY              11/29/2002                F
#
#   Crash Time Police Department Code
# 0       1850                     01
# 1       1727                     01

# %%
df_sample1[columns2].head(4)
# Out:
#     Police Station  Total Killed  Total Injured  Pedestrians Killed  \
# 0  MUNICIPAL COMP?             0              0                   0
# 1  MUNICIPAL COMP?             0              2                   0
# 2                              0              2                   0
# 3  MUNICIPAL COMP?             0              0                   0
#
#    Pedestrians Injured Severity Intersection Alcohol Involved HazMat Involved  \
# 0                    0        P            B                Y               N
# 1                    0        I            I                N               N
# 2                    0        I            B                N               N
# 3                    0        P            I                N               N
#
#    Crash Type Code  Total Vehicles Involved  \
# 0                1                        2
# 1                7                        2
# 2                1                        3
# 3                3                        2
#
# ...

# %%
df_sample1.rename({20:'Location Direction',21:'Route',22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction'},axis=1,inplace=True)
df_sample1.head(4)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20020101#02-3806                 ATLANTIC      ABSECON CITY
# 1  20020101#2002-19775              ATLANTIC      ABSECON CITY
# 2  2002010101-4114                  ATLANTIC      ABSECON CITY
# 3  2002010102-001140                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  02/26/2002                TU       1850                     01
# 1  11/29/2002                F        1727                     01
# 2  03/03/2002                S        1448
# 3  01/20/2002                S        0025
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ABSECON CITY               MUNICIPAL COMP?             0  ...
# 1  ABSECON CITY               MUNICIPAL COMP?             0  ...
# 2  ABSECON CITY                                           0  ...
# 3  ABSECON                    MUNICIPAL COMP?             0  ...
#
# ...

# %%
columns3 = ['Location Direction','Route','Route Suffix','SRI (Standard Route Indentifier)','Mile Post','Road System','Road Character','Road Surface Type','Surface Condition','Light Condition','Enviornmental Condition','Road Divided By','Temporary Traffic Control Zone','Distance to Cross Street','Unit of Measurement','Direction from Cross Street','Cross Street Name','Is Ramp','Ramp To/From Route Name','Ramp To/From Direction']

# %%
df_sample1.rename({40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},axis=1,inplace=True)

# %%
columns4 = ['Posted Speed','Posted Speed Cross Street','Latitude','Longitude','Cell Phone In Use Flag','Other Property Damage','Reporting Badge No.']
df_sample1[columns4].head(4)
# Out:
#    Posted Speed Posted Speed Cross Street  Latitude Longitude  \
# 0            50
# 1            40
# 2            40
# 3            35
#
#   Cell Phone In Use Flag                              Other Property Damage  \
# 0                      N  NONE (8) SUMMONS-#A047283 84 85 86 87 88 89 90...
# 1                      N  NONE                                          ...
# 2                      N  NONE                                          ...
# 3                      N                                                ...
#
#   Reporting Badge No.
# 0               830
# 1               830
# 2               833
# 3               835

# %%
df_sample1.info(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319979 entries, 0 to 319978
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          319979 non-null  object
#  1   County Name                       319979 non-null  object
#  2   Municipality Name                 319979 non-null  object
#  3   Crash Date                        319979 non-null  object
#  4   Crash Day of Week                 319979 non-null  object
#  5   Crash Time                        319979 non-null  object
#  6   Police Department Code            319979 non-null  object
#  7   Police Department                 319979 non-null  object
#  8   Police Station                    319979 non-null  object
#  9   Total Killed                      319979 non-null  int64
#  10  Total Injured                     319979 non-null  int64
# ...

# %%
df_merge1 = df_sample.append(df_sample1, ignore_index=True)

# %%
df_merge1.head(5)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20010101#2001-17846              ATLANTIC      ABSECON CITY
# 1  2001010101-00029                 ATLANTIC      ABSECON CITY
# 2  2001010101-004615                ATLANTIC      ABSECON CITY
# 3  2001010101-004880                ATLANTIC      ABSECON CITY
# 4  2001010101-004912                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  12/21/2001                F        1834                     01
# 1  01/01/2001                M        0930                     1
# 2  04/10/2001                TU       1444                     1
# 3  04/15/2001                S        1356                     1
# 4  04/16/2001                M        1029                     1
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ABSECON CITY               MUNICIPAL COMP?             0  ...
# ...

# %%
df_merge1.tail(3)
# Out:
#                                Crash_ID   County Name  \
# 632672  20022123B1500295A                WARREN
# 632673  20022123B1500296A                WARREN
# 632674  20022123B150200202208A           WARREN
#
#                Municipality Name  Crash Date Crash Day of Week Crash Time  \
# 632672  WHITE TWP                 04/10/2002                W        1139
# 632673  WHITE TWP                 04/16/2002                TU       1650
# 632674  WHITE TWP                 08/27/2002                TU       1334
#
#        Police Department Code          Police Department   Police Station  \
# 632672                     02  STATE POLICE               WASHINGTON
# 632673                     2   STATE POLICE               WASHINGTON
# 632674                     2   STATE POLICE               WASHINGTON
#
#         Total Killed  ...    Ramp To/From Route Name  Ramp To/From Direction  \
# 632672             0  ...
# 632673             0  ...
# 632674             0  ...
#
# ...

# %%
df_merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632675 entries, 0 to 632674
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          632675 non-null  object
#  1   County Name                       632675 non-null  object
#  2   Municipality Name                 632675 non-null  object
#  3   Crash Date                        632675 non-null  object
#  4   Crash Day of Week                 632675 non-null  object
#  5   Crash Time                        632675 non-null  object
#  6   Police Department Code            632675 non-null  object
#  7   Police Department                 632675 non-null  object
#  8   Police Station                    632675 non-null  object
#  9   Total Killed                      632675 non-null  int64
#  10  Total Injured                     632675 non-null  float64
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2003Accidents.txt',sep=',',header=None)

# %%
df2.head(3)
# Out:
#                                 0             1                         2   \
# 0  2003010102-007854                ATLANTIC      ABSECON CITY
# 1  2003010103-003263                ATLANTIC      ABSECON CITY
# 2  2003010103-006356                ATLANTIC      ABSECON CITY
#
#            3   4     5   6                          7                8   9   \
# 0  04/29/2003  TU  0726      ABSECON                    MUNICIPAL COMP?   0
# 1  03/13/2003  TH  0208  1   ABSECON CITY               MUNICIPAL COMP?   0
# 2  05/20/2003  TU  2348  1   ABSECON                    MUNICIPAL COMP?   0
#
#    ...  37                         38  39  40  41        42        43  44  \
# 0  ...                                     50                           N
# 1  ...                                     25                           N
# 2  ...                                     40                           N
#
#                                                   45     46
# ...

# %%
df2['Year'] = 2003

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324053 entries, 0 to 324052
# Data columns (total 48 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       324053 non-null  object
#  1   1       324053 non-null  object
#  2   2       324053 non-null  object
#  3   3       324053 non-null  object
#  4   4       324053 non-null  object
#  5   5       324053 non-null  object
#  6   6       324053 non-null  object
#  7   7       324053 non-null  object
#  8   8       324053 non-null  object
#  9   9       324053 non-null  int64
#  10  10      324053 non-null  int64
#  11  11      324053 non-null  int64
#  12  12      324053 non-null  int64
#  13  13      324053 non-null  object
#  14  14      324053 non-null  object
#  15  15      324053 non-null  object
#  16  16      324053 non-null  object
#  17  17      324053 non-null  int64
#  18  18      324053 non-null  int64
#  19  19      324053 non-null  object
# ...

# %%
df_sample2 = df2.copy()

# %%
df_sample2.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department'}, axis=1, inplace=True)

# %%
df_sample2[columns1].head(2)
# Out:
#     County Name         Municipality Name  Crash Date Crash Day of Week  \
# 0  ATLANTIC      ABSECON CITY              04/29/2003                TU
# 1  ATLANTIC      ABSECON CITY              03/13/2003                TH
#
#   Crash Time Police Department Code
# 0       0726
# 1       0208                     1

# %%
df_sample2.rename({8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed', 12:'Pedestrians Injured', 13:'Severity', 14:'Intersection', 15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location'}, axis=1, inplace=True)

# %%
df_sample2[columns2].head(3)
# Out:
#     Police Station  Total Killed  Total Injured  Pedestrians Killed  \
# 0  MUNICIPAL COMP?             0              0                   0
# 1  MUNICIPAL COMP?             0              0                   0
# 2  MUNICIPAL COMP?             0              2                   0
#
#    Pedestrians Injured Severity Intersection Alcohol Involved HazMat Involved  \
# 0                    0        P            B                N               N
# 1                    0        P            B                N               N
# 2                    0        I            B                Y               N
#
#    Crash Type Code  Total Vehicles Involved  \
# 0               11                        1
# 1                6                        2
# 2                4                        2
#
#                                       Crash Location
# 0  US 30                                         ...
# 1  LAVENDER LN                                   ...
# ...

# %%
df_sample2.rename({20:'Location Direction',21:'Route',22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction'},axis=1,inplace=True)
df_sample2.head(4)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  2003010102-007854                ATLANTIC      ABSECON CITY
# 1  2003010103-003263                ATLANTIC      ABSECON CITY
# 2  2003010103-006356                ATLANTIC      ABSECON CITY
# 3  2003010103-007018                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  04/29/2003                TU       0726
# 1  03/13/2003                TH       0208                     1
# 2  05/20/2003                TU       2348                     1
# 3  06/05/2003                TH       1318                     1
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ABSECON                    MUNICIPAL COMP?             0  ...
# 1  ABSECON CITY               MUNICIPAL COMP?             0  ...
# 2  ABSECON                    MUNICIPAL COMP?             0  ...
# 3  ABSECON                                                0  ...
# ...

# %%
df_sample2.rename({40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},axis=1,inplace=True)

# %%
df_sample2[columns4].head(2)
# Out:
#    Posted Speed Posted Speed Cross Street  Latitude Longitude  \
# 0            50
# 1            25
#
#   Cell Phone In Use Flag                              Other Property Damage  \
# 0                      N                                                ...
# 1                      N                                                ...
#
#   Reporting Badge No.
# 0               835
# 1               835

# %%
df_merge2 = df_merge1.append(df_sample2, ignore_index=True)

# %%
df_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956728 entries, 0 to 956727
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Crash_ID                          956728 non-null  object
#  1   County Name                       956728 non-null  object
#  2   Municipality Name                 956728 non-null  object
#  3   Crash Date                        956728 non-null  object
#  4   Crash Day of Week                 956728 non-null  object
#  5   Crash Time                        956728 non-null  object
#  6   Police Department Code            956728 non-null  object
#  7   Police Department                 956728 non-null  object
#  8   Police Station                    956728 non-null  object
#  9   Total Killed                      956728 non-null  int64
#  10  Total Injured                     956728 non-null  float64
# ...

# %%
df_merge2.tail(3)
# Out:
#                                Crash_ID   County Name  \
# 956725  20032123OIT-03175784             WARREN
# 956726  20032123OIT-03187287             WARREN
# 956727  20032123OIT-03210024             WARREN
#
#                Municipality Name  Crash Date Crash Day of Week Crash Time  \
# 956725  WHITE TWP                 07/20/2003                S        1519
# 956726  WHITE TWP                 08/03/2003                S        1320
# 956727  WHITE TWP                 08/16/2003                SA       1840
#
#        Police Department Code          Police Department   Police Station  \
# 956725                     2   ?                          WASHINGTON
# 956726                     2   STATE POLICE               WASHINGTON
# 956727                     2   STATE POLICE               WASHINGTON
#
#         Total Killed  ...    Ramp To/From Route Name  Ramp To/From Direction  \
# 956725             0  ...
# 956726             0  ...
# 956727             0  ...
#
# ...

# %%
df3 = pd.read_csv('/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NewJersey2004Accidents.txt',sep=',',header=None)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323419 entries, 0 to 323418
# Data columns (total 47 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       323419 non-null  object
#  1   1       323419 non-null  object
#  2   2       323419 non-null  object
#  3   3       323419 non-null  object
#  4   4       323419 non-null  object
#  5   5       323419 non-null  object
#  6   6       323419 non-null  object
#  7   7       323419 non-null  object
#  8   8       323419 non-null  object
#  9   9       323419 non-null  int64
#  10  10      323419 non-null  int64
#  11  11      323419 non-null  int64
#  12  12      323419 non-null  int64
#  13  13      323419 non-null  object
#  14  14      323419 non-null  object
#  15  15      323419 non-null  object
#  16  16      323419 non-null  object
#  17  17      323419 non-null  int64
#  18  18      323419 non-null  int64
#  19  19      323419 non-null  object
# ...

# %%
df3['Year'] = 2004

# %%
df3.head(2)
# Out:
#                                  0             1                         2  \
# 0  20040101#20004-14225             ATLANTIC      ABSECON CITY
# 1  20040101#2004-10356              ATLANTIC      ABSECON CITY
#
#             3   4     5   6                          7                8  9  \
# 0  12/07/2004  TU  1038  1   ABSECON                    MUNICIPAL COMP?  0
# 1  09/03/2004  F   1027  1   ABSECON                    MUNICIPAL COMP?  0
#
#    ...                         38  39  40  41        42        43 44  \
# 0  ...                                 50                          N
# 1  ...                                 35                          N
#
#                                                   45     46  Year
# 0  NONE                                          ...  830    2004
# 1  TRAFFIC LIGHT SIGNAL/LANDSCAPING AT CAR WASH/T...  830    2004
#
# [2 rows x 48 columns]

# %%
df_sample3 = df3.copy()

# %%
df_sample3.rename({0: 'Crash_ID', 1:'County Name',2:'Municipality Name',3:'Crash Date',4:'Crash Day of Week',5:'Crash Time',6:'Police Department Code', 7:'Police Department'}, axis=1, inplace=True)

# %%
df_sample3.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20040101#20004-14225             ATLANTIC      ABSECON CITY
# 1  20040101#2004-10356              ATLANTIC      ABSECON CITY
# 2  20040101#2004-10362              ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  12/07/2004                TU       1038                     1
# 1  09/03/2004                F        1027                     1
# 2  09/03/2004                F        1317                     1
#
#            Police Department                8  9  ...  \
# 0  ABSECON                    MUNICIPAL COMP?  0  ...
# 1  ABSECON                    MUNICIPAL COMP?  0  ...
# 2  ABSECON                    MUNICIPAL COMP?  0  ...
#
#                           38  39  40  41        42        43 44  \
# 0                                 50                          N
# 1                                 35                          N
# ...

# %%
df_sample3.rename({8:'Police Station', 9:'Total Killed', 10:'Total Injured', 11:'Pedestrians Killed', 12:'Pedestrians Injured', 13:'Severity', 14:'Intersection', 15:'Alcohol Involved', 16:'HazMat Involved', 17:'Crash Type Code', 18:'Total Vehicles Involved', 19:'Crash Location'}, axis=1, inplace=True)

# %%
df_sample3[columns2].head(3)
# Out:
#     Police Station  Total Killed  Total Injured  Pedestrians Killed  \
# 0  MUNICIPAL COMP?             0              1                   0
# 1  MUNICIPAL COMP?             0              1                   0
# 2  MUNICIPAL COMP?             0              0                   0
#
#    Pedestrians Injured Severity Intersection Alcohol Involved HazMat Involved  \
# 0                    0        I            B                N               N
# 1                    0        I            I                N               N
# 2                    0        P            B                N               N
#
#    Crash Type Code  Total Vehicles Involved  \
# 0                1                        2
# 1                7                        2
# 2                3                        2
#
#                                       Crash Location
# 0  US 30                                         ...
# 1  US 9                                          ...
# ...

# %%
df_sample3.rename({20:'Location Direction',21:'Route',22:'Route Suffix',23:'SRI (Standard Route Indentifier)',24:'Mile Post',25:'Road System',26:'Road Character',27:'Road Surface Type',28:'Surface Condition',29:'Light Condition',30:'Enviornmental Condition',31:'Road Divided By',32:'Temporary Traffic Control Zone',33:'Distance to Cross Street',34:'Unit of Measurement',35:'Direction from Cross Street',36:'Cross Street Name',37:'Is Ramp',38:'Ramp To/From Route Name',39:'Ramp To/From Direction'},axis=1,inplace=True)

# %%
df_sample3[columns3].head(3)
# Out:
#   Location Direction Route Route Suffix SRI (Standard Route Indentifier)  \
# 0                       30                              00000030__
# 1                        9                              00000009__
# 2                      651                              01000651__
#
#   Mile Post  Road System Road Character Road Surface Type Surface Condition  \
# 0     54.11            2             04                02                02
# 1     42.74            2             01                02                01
# 2     12.02            5             01                02                01
#
#   Light Condition Enviornmental Condition Road Divided By  \
# 0              01                      02              01
# 1              01                      01              05
# 2              01                      01              05
#
#   Temporary Traffic Control Zone Distance to Cross Street Unit of Measurement  \
# ...

# %%
df_sample3.rename({40:'Posted Speed',41:'Posted Speed Cross Street',42:'Latitude',43:'Longitude',44:'Cell Phone In Use Flag', 45:'Other Property Damage', 46:'Reporting Badge No.'},axis=1,inplace=True)

# %%
df_sample3[columns4].head(3)
# Out:
#    Posted Speed Posted Speed Cross Street  Latitude Longitude  \
# 0            50
# 1            35
# 2            35
#
#   Cell Phone In Use Flag                              Other Property Damage  \
# 0                      N  NONE                                          ...
# 1                      N  TRAFFIC LIGHT SIGNAL/LANDSCAPING AT CAR WASH/T...
# 2                      N  NONE                                          ...
#
#   Reporting Badge No.
# 0               830
# 1               830
# 2               830

# %%
df_merge3 = df_merge2.append(df_sample3, ignore_index=True)

# %%
df_merge3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280147 entries, 0 to 1280146
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   Crash_ID                          1280147 non-null  object
#  1   County Name                       1280147 non-null  object
#  2   Municipality Name                 1280147 non-null  object
#  3   Crash Date                        1280147 non-null  object
#  4   Crash Day of Week                 1280147 non-null  object
#  5   Crash Time                        1280147 non-null  object
#  6   Police Department Code            1280147 non-null  object
#  7   Police Department                 1280147 non-null  object
#  8   Police Station                    1280147 non-null  object
#  9   Total Killed                      1280147 non-null  int64
#  10  Total Injured                     1280147 non-null  float64
# ...

# %%
df_merge3.tail(3)
# Out:
#                                 Crash_ID   County Name  \
# 1280144  20042123B?50200400030A           WARREN
# 1280145  20042123OIT-04284737             WARREN
# 1280146  20042123OIT-04305526             WARREN
#
#                 Municipality Name  Crash Date Crash Day of Week Crash Time  \
# 1280144  WHITE TWP                 01/21/2004                W        1937
# 1280145  WHITE TWP                 11/20/2004                SA
# 1280146  WHITE TWP                 12/04/2004                SA       1130
#
#         Police Department Code          Police Department   Police Station  \
# 1280144                     2   STATE POLICE               WASHINGTON
# 1280145                     2   ?                          ?
# 1280146                     2   STATE POLICE               WASHINGTON
#
#          Total Killed  ...    Ramp To/From Route Name  Ramp To/From Direction  \
# 1280144             0  ...
# 1280145             0  ...
# 1280146             0  ...
#
# ...

# %%
df_merge3.head(3)
# Out:
#                           Crash_ID   County Name         Municipality Name  \
# 0  20010101#2001-17846              ATLANTIC      ABSECON CITY
# 1  2001010101-00029                 ATLANTIC      ABSECON CITY
# 2  2001010101-004615                ATLANTIC      ABSECON CITY
#
#    Crash Date Crash Day of Week Crash Time Police Department Code  \
# 0  12/21/2001                F        1834                     01
# 1  01/01/2001                M        0930                     1
# 2  04/10/2001                TU       1444                     1
#
#            Police Department   Police Station  Total Killed  ...  \
# 0  ABSECON CITY               MUNICIPAL COMP?             0  ...
# 1  ABSECON                                                0  ...
# 2  ABSECON                                                0  ...
#
#      Ramp To/From Route Name  Ramp To/From Direction  Posted Speed  \
# 0                                                               25
# ...

# %%
from google.colab import drive

#drive.mount('/content/drive')
#path = '/content/drive/MyDrive/NJ_Mine/Crash, Raw txt Files/NJ_Accidents(2001-2004).csv'

#with open(path, 'w', encoding = 'utf-8-sig') as f:
  #df_merge3.to_csv(f)
